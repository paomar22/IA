# %%
import numpy as np 
#np.random.seed(0)

def sigmoid (x):
    return 1/(1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

#Input datasets
inputs = np.array([[0,0],[0,1],[1,0],[1,1]])
expected_output = np.array([[0],[1],[1],[0]])

epochs = 10000
lr = 0.1
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2,2,1

#Random weights and bias initialization
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons))
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_bias = np.random.uniform(size=(1,outputLayerNeurons))

print("Initial hidden weights: ",end='')
print(*hidden_weights)
print("Initial hidden biases: ",end='')
print(*hidden_bias)
print("Initial output weights: ",end='')
print(*output_weights)
print("Initial output biases: ",end='')
print(*output_bias)


#Training algorithm
for _ in range(epochs):
	#Forward Propagation
	hidden_layer_activation = np.dot(inputs,hidden_weights)
	hidden_layer_activation += hidden_bias
	hidden_layer_output = sigmoid(hidden_layer_activation)

	output_layer_activation = np.dot(hidden_layer_output,output_weights)
	output_layer_activation += output_bias
	predicted_output = sigmoid(output_layer_activation)

	#Backpropagation
	error = expected_output - predicted_output
	d_predicted_output = error * sigmoid_derivative(predicted_output)
	
	error_hidden_layer = d_predicted_output.dot(output_weights.T)
	d_hidden_layer = error_hidden_layer * sigmoid_derivative(hidden_layer_output)

	#Updating Weights and Biases
	output_weights += hidden_layer_output.T.dot(d_predicted_output) * lr
	output_bias += np.sum(d_predicted_output,axis=0,keepdims=True) * lr
	hidden_weights += inputs.T.dot(d_hidden_layer) * lr
	hidden_bias += np.sum(d_hidden_layer,axis=0,keepdims=True) * lr

print("Final hidden weights: ",end='')
print(*hidden_weights)
print("Final hidden bias: ",end='')
print(*hidden_bias)
print("Final output weights: ",end='')
print(*output_weights)
print("Final output bias: ",end='')
print(*output_bias)

print("\nOutput from neural network after 10,000 epochs: ",end='')
print(*predicted_output)
# Out:
# Initial hidden weights: [0.25150105 0.99549233] [0.50040517 0.94756261]
# Initial hidden biases: [0.34796508 0.26230838]
# Initial output weights: [0.38396575] [0.2124355]
# Initial output biases: [0.1098208]
# Final hidden weights: [3.76241187 5.84005483] [3.76734893 5.86439726]
# Final hidden bias: [-5.7669489  -2.45529165]
# Final output weights: [-8.25332382] [7.60458577]
# Final output bias: [-3.42910971]
#
# Output from neural network after 10,000 epochs: [0.05449521] [0.95015814] [0.9500856] [0.05366315]

# %%
import numpy as np 
#np.random.seed(0)

def sigmoid (x):
    return 1/(1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

#Input datasets
inputs = np.array([[0,0],[0,1],[1,0],[1,1]])
expected_output = np.array([[0],[1],[1],[0]])

epochs = 10000
lr = 0.1
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2,2,1

#Random weights and bias initialization
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
#hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons))
hidden_weight_b =np.random.uniform(size=(inputLayerNeurons))
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_weight_b= np.random.uniform(size=(outputLayerNeurons))
#output_bias = np.random.uniform(size=(1,outputLayerNeurons))

print("Initial hidden weights: ",end='')
print(*hidden_weights)
print("Initial hidden weight b: ",end='')
print(*hidden_weight_b)
print("Initial output weights: ",end='')
print(*output_weights)
print("Initial output weight b: ",end='')
print(*output_weight_b)


#Training algorithm
for i in range(epochs):
    for j in range(4):
        #foward
        z=np.dot(inputs,hidden_weights)+hidden_weight_b
        a=sigmoid(z)
        y_hat=np.dot(a,output_weights)+output_weight_b
        y_hat_activation=sigmoid(y_hat)
        #backpropagation
        #output
        #hidden
print(y_hat)
# Out:
# Initial hidden weights: [0.6601906  0.78978837] [0.49091993 0.63785052]
# Initial hidden weight b: 0.009960330096712378 0.8278763265122387
# Initial output weights: [0.31327691] [0.56549917]
# Initial output weight b: 0.997965127202327
# [[1.54891776]
#  [1.65244755]
#  [1.67710306]
#  [1.74838158]]

# %%
import numpy as np 
#np.random.seed(0)

def sigmoid (x):
    return 1/(1 + np.exp(-x))


#Input datasets
inputs = np.array([[0,0],[0,1],[1,0],[1,1]])
expected_output = np.array([[0],[1],[1],[0]])

epochs = 10000
lr = 0.1
inputLayerNeurons, hiddenLayerNeurons, outputLayerNeurons = 2,2,1

#Random weights and bias initialization
hidden_weights = np.random.uniform(size=(inputLayerNeurons,hiddenLayerNeurons))
#hidden_bias =np.random.uniform(size=(1,hiddenLayerNeurons))
hidden_weight_b =np.random.uniform(size=(inputLayerNeurons))
output_weights = np.random.uniform(size=(hiddenLayerNeurons,outputLayerNeurons))
output_weight_b= np.random.uniform(size=(outputLayerNeurons))
#output_bias = np.random.uniform(size=(1,outputLayerNeurons))

print("Initial hidden weights: ",end='')
print(*hidden_weights)
print("Initial hidden weight b: ",end='')
print(*hidden_weight_b)
print("Initial output weights: ",end='')
print(*output_weights)
print("Initial output weight b: ",end='')
print(*output_weight_b)

w1_actualization=0
w2_actualization=0
b2_actualization=0

w_1_1_actualization=0
w_1_2_actualization=0
w_2_1_actualization=0
w_2_2_actualization=0
b_1_actualization=0
b_2_actualization=0
        
#Training algorithm
for i in range(epochs):
    for j in range(1):
        #foward
        z=np.dot(inputs,hidden_weights)+hidden_weight_b
        a=sigmoid(z)
        y_hat=np.dot(a,output_weights)+output_weight_b
        #y_hat_activation=sigmoid(y_hat)
        #backpropagation
        #output
        error = expected_output - y_hat
        w1_predicted_output =(-2 * error)*a[0][0] #W1(2)
        w2_predicted_output =(-2 * error)*a[0][1] #W2(2)
        b2_predicted_output =(-2 * error)#b(2)
        
        #actualizacion de parametros output
        w1_actualization+=lr*(w1_predicted_output*-1)
        w2_actualization+=lr*(w2_predicted_output*-1)
        b2_actualization+=lr*(b2_predicted_output*-1)
        
        #hidden
        w_1_1_hidden=(-2*error*w1_actualization)*(a[0][0]*(1-a[0][0]))*(inputs[0][0])
        w_1_2_hidden=(-2*error*w1_actualization)*(a[0][1]*(1-a[0][1]))*(inputs[0][1])
        w_2_1_hidden=(-2*error*w2_actualization)*(a[0][0]*(1-a[0][0]))*(inputs[0][0])
        w_2_2_hidden=(-2*error*w2_actualization)*(a[0][1]*(1-a[0][1]))*(inputs[0][1])
        b_1_hidden=(-2*error)
        b_2_hidden=(-2*error)
        
        #actualizacion de parametros
        w_1_1_actualization+=lr*w_1_1_hidden*-1
        w_1_2_actualization+=lr*w_1_2_hidden*-1
        w_2_1_actualization+=lr*w_2_1_hidden*-1
        w_2_2_actualization+=lr*w_2_2_hidden*-1
        b_1_actualization+=lr*b_1_hidden*-1
        b_2_actualization+=lr*b_2_hidden*-1
        
        
print("\nOutput from neural network after 10,000 epochs: ",end='')
print(*y_hat)       
#print(inputs)
#print(hidden_weights)
#print(hidden_weight_b)
#print(z)
#print(a)
#print(a[0][0])
#print(y_hat)
#print(error)
#print(d_predicted_output)
# Out:
# Initial hidden weights: [0.3199333 0.7905359] [0.96286634 0.66087638]
# Initial hidden weight b: 0.015402333359501252 0.5359525558074687
# Initial output weights: [0.95507987] [0.94685833]
# Initial output weight b: 0.8199829837782594
#
# Output from neural network after 10,000 epochs: [1.89854533] [2.24125067] [2.12511253] [2.40295688]
